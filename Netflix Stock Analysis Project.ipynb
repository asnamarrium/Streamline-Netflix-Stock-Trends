# %% [markdown]
# # Netflix-StockStream

# %% [markdown]
# # 1. Import Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# # 2. Load the Netflix Stock Dataset

# %%
df = pd.read_csv("netflix.csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-01-04    7.931429    7.961429    7.565714    7.640000    7.640000
# 1     2010-01-05    7.652857    7.657143    7.258571    7.358571    7.358571
# 2     2010-01-06    7.361429    7.672857    7.197143    7.617143    7.617143
# 3     2010-01-07    7.731429    7.757143    7.462857    7.485714    7.485714
# 4     2010-01-08    7.498571    7.742857    7.465714    7.614286    7.614286
# ...          ...         ...         ...         ...         ...         ...
# 3114  2022-05-17  189.169998  191.399994  185.169998  190.559998  190.559998
# 3115  2022-05-18  186.720001  187.699997  176.270004  177.190002  177.190002
# 3116  2022-05-19  178.050003  186.300003  175.710007  183.479996  183.479996
# 3117  2022-05-20  185.869995  190.190002  179.770004  186.350006  186.350006
# 3118  2022-05-23  186.149994  187.660004  177.889999  187.440002  187.440002
#
#         Volume
# 0     17239600
# 1     23753100
# 2     23290400
# 3      9955400
# 4      8180900
# ...        ...
# 3114   9876700
# 3115   9665600
# 3116  10448500
# 3117  10422600
# 3118   9558000
#
# [3119 rows x 7 columns]

# %% [markdown]
# # 3.  Preprocess & Set Date as Index

# %%
df['Date']=pd.to_datetime(df['Date'])
df = df.set_index('Date')
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2010-01-04  7.931429  7.961429  7.565714  7.640000   7.640000  17239600
# 2010-01-05  7.652857  7.657143  7.258571  7.358571   7.358571  23753100
# 2010-01-06  7.361429  7.672857  7.197143  7.617143   7.617143  23290400
# 2010-01-07  7.731429  7.757143  7.462857  7.485714   7.485714   9955400
# 2010-01-08  7.498571  7.742857  7.465714  7.614286   7.614286   8180900

# %% [markdown]
# # 4. Configure Plot Style

# %%
sns.set(rc={'figure.figsize':(10,5)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sns.set(rc={'figure.figsize':(10,5)})
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ## 5. 📈 Stock Trading Volume Over Time

# %%
sns.lineplot(x=df.index, y=df['Volume'],label='Volume')
plt.title('Volume of stock versus time')
plt.show()
# Out:
# C:\Users\asna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\asna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # 6. 💹 High, Open, and Close Stock Prices

# %%
df.plot(y = ['High','Open','Close'], title = 'Netflix Stock Price')
plt.show()

# %% [markdown]
# # 7. 📅 Volume Trends by Day, Month & Year

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,figsize=(15,10))
df.groupby(df.index.day).mean().plot(y = 'Volume', ax=ax1, xlabel = 'Day')
df.groupby(df.index.month).mean().plot(y = 'Volume', ax=ax2, xlabel = 'Month')
df.groupby(df.index.year).mean().plot(y = 'Volume', ax=ax3, xlabel = 'Year')
plt.show()

# %% [markdown]
# # 8. 🚀 Top 5 Days with Highest Stock Price

# %%
a = df.sort_values(by = 'High', ascending = False).head(5)
a['High']
# Out:
# Date
# 2021-11-17    700.989990
# 2021-11-19    694.159973
# 2021-11-18    691.739990
# 2021-10-29    690.969971
# 2021-11-01    689.969971
# Name: High, dtype: float64

# %% [markdown]
# # 9. 📉 Top 5 Days with Lowest Stock Price

# %%
b = df.sort_values(by = 'Low' , ascending = True).head(5)
b['Low']
# Out:
# Date
# 2010-01-25    6.931429
# 2010-01-26    6.937143
# 2010-01-27    6.992857
# 2010-01-06    7.197143
# 2010-01-21    7.214286
# Name: Low, dtype: float64

# %% [markdown]
# # 10. Draw 2 different Graphs showing Low & High stock

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2, sharex = True, figsize = (12,5))
fig.suptitle("High & Low values Stock per period of Time",fontsize = 18)
sns.lineplot(ax =axes[0],y = df['High'], x = df.index, color = 'green')
sns.lineplot(ax =axes[1],y = df['Low'], x = df.index, color = 'red')
# Out:
# C:\Users\asna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\asna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\asna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\asna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Date', ylabel='Low'>
